# %%
import pandas as pd

# %%
import plotly.express as px

# %%
df_1 = pd.read_csv("wandb_export_2025-01-28T09_35_09.318+01_00.csv")
df_2 = pd.read_csv("wandb_export_2025-01-28T09_34_59.425+01_00.csv")

# %%
df_1 = df_1.drop(columns=[col for col in df_1.columns if "__" in col])
df_2 = df_2.drop(columns=[col for col in df_2.columns if "__" in col])

# %%
# make tables from wide to long
df_1 = df_1.melt(id_vars=["Step"], var_name="Algorithm", value_name="Global Step")
df_2 = df_2.melt(id_vars=["Step"], var_name="Algorithm", value_name="Success Rate")

# %%
df_1 = df_1.dropna(subset=["Global Step"])
df_2 = df_2.dropna(subset=["Success Rate"])

# %%
df_1.Algorithm = df_1.Algorithm.apply(lambda x: x.split("-")[0].strip())
df_2.Algorithm = df_2.Algorithm.apply(lambda x: x.split("-")[0].strip())

# %%
df_1 = df_1.merge(df_2, on=["Step", "Algorithm"], how="inner")

# %%
df_1.Algorithm = df_1.Algorithm.replace(
    {
        "eager": "CrossQ",
        "jumping": "SAC",
        "ruby": "TQC",
        "comfy": "TD3",
        "solar": "DDPG",
        "avid": "TRPO",
        "rose": "A2C", 
        "noble": "PPO",
    }
)

# %%
fig = px.line(
    df_1,
    x="Global Step",
    y="Success Rate",
    color="Algorithm",
    line_shape="spline",
    title="Success Rate over Global Step",
)

# %%
fig.show()
fig.write_html("success_rate.html")
# Out:
# <div>                            <div id="0ec49306-3925-4f04-af5a-8f43c5c6533a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ec49306-3925-4f04-af5a-8f43c5c6533a")) {                    Plotly.newPlot(                        "0ec49306-3925-4f04-af5a-8f43c5c6533a",                        [{"hovertemplate":"Algorithm=TRPO\u003cbr\u003eGlobal Step=%{x}\u003cbr\u003eSuccess Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TRPO","line":{"color":"#636efa","dash":"solid","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines","name":"TRPO","orientation":"v","showlegend":true,"x":[2048.0,4096.0,6144.0,8192.0,10240.0,12288.0,14336.0,16384.0,18432.0,20480.0,22528.0,24576.0,26624.0,28672.0,30720.0,32768.0,34816.0,36864.0,38912.0,40960.0,43008.0,45056.0,47104.0,49152.0,51200.0,53248.0,55296.0,57344.0,59392.0,61440.0,63488.0,65536.0,67584.0,69632.0,71680.0,73728.0,75776.0,77824.0,79872.0,81920.0,83968.0,86016.0,88064.0,90112.0,92160.0,94208.0,96256.0,98304.0,100352.0,102400.0,104448.0,106496.0,108544.0,110592.0,112640.0,114688.0,116736.0,118784.0,120832.0,122880.0,124928.0,126976.0,129024.0,131072.0,133120.0,135168.0,137216.0,139264.0,141312.0,143360.0,145408.0,147456.0,149504.0,151552.0,153600.0,155648.0,157696.0,159744.0,161792.0,163840.0,165888.0,167936.0,169984.0,172032.0,174080.0,176128.0,178176.0,180224.0,182272.0